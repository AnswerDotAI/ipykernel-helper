# %% [markdown]
# # ipykernel-helper
#
# > Helpers for ipykernel and friends

# %% [markdown]
# There's not many helpers here yet!

# %% [markdown]
# ## Installation

# %% [markdown]
# Install latest from [pypi](https://pypi.org/project/ipykernel-helper/)
#
#
# ```sh
# $ pip install ipykernel_helper
# ```

# %% [markdown]
# ## How to use

# %%
from ipykernel_helper import *
from pprint import pprint

# %%
a = "hi"
b = dict(d='foo ' * 10)
def f(i:int): ...

# %%
_vs,_fs = user_items(globals(), max_len=15)
print('--- vars')
pprint(_vs)
print('--- defs')
pprint(_fs)
# Out:
# --- vars
# {'a': 'hi', 'b': "{'d': 'foo foo …"}
# --- defs
# {'f': '(i: int)'}
